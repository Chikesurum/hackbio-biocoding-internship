# %% [markdown]
# ## Alex stressed me to do this

# %%
Isoleucine_group = { # A dictionary named Isoleucine_group was created
    

"Chikesurum": # Created a list named Chikesurum
{"Full name": "Chikesurum Woha",
"Slack username": "Chikesurum",
 "Email address": "chikesurum@gmail.com",
 "Hobby": "painting",
  "Country": "United Kingdom",
  "Discipline": "Biotechnology",
  "Preferred Language": "Python"},


"Zivah":
{"Full name": "Zivah Woha",
"Slack username": "Zivah",
"Email address": "zivah@gmail.com",
"Hobby": "playing games",
"Country": "United Kingdom",
"Discipline": "medicine",
"Preferred Language": "Python"},


"Beulah":
{"Full name": "Beulah Agu",
"Slack username": "Beulah",
"Email address": "Beulah@gmail.com",
"Hobby": "singing",
"Country": "Nigeria",
"Discipline": "Biology",
"Preferred Language": "Python"},


"Feyisola":
{"Full name": "Feyisola Adeyemi",
"Slack username": "Feyisola",
"Email address": "Feyisola@gmail.com",
"Hobby": "swimming",
"Country": "United Kingdom",
"Discipline": "Biotechnology",
"Preferred Language": "Python"},


"Irene":
{"Full name": "Irene Abiodun",
"Slack username": "Irene",
"Email address": "Irene@gmail.com",
"Hobby": "swimming",
"Country": "United Kingdom",
"Discipline": "Biotechnology",
"Preferred Language": "Python"} }

# %% [markdown]
# ### Result

# %%
print("RESULTS FOR ISOLEUCINE GROUP")
print("\n")

print(1)
print("Full Name:", Isoleucine_group["Chikesurum"]["Full name"])
print("Slack Username:", Isoleucine_group["Chikesurum"]["Slack username"])
print("Email:", Isoleucine_group["Chikesurum"]["Email address"])
print("Hobby:", Isoleucine_group["Chikesurum"]["Hobby"])
print("Country:", Isoleucine_group["Chikesurum"]["Country"])
print("Discipline:", Isoleucine_group["Chikesurum"]["Discipline"])
print("Preferred Language:", Isoleucine_group["Chikesurum"]["Preferred Language"])
print("\n")  # Adds a blank line for readability

print(2)
print("Full Name:", Isoleucine_group["Zivah"]["Full name"])
print("Slack Username:", Isoleucine_group["Zivah"]["Slack username"])
print("Email:", Isoleucine_group["Zivah"]["Email address"])
print("Hobby:", Isoleucine_group["Zivah"]["Hobby"])
print("Country:", Isoleucine_group["Zivah"]["Country"])
print("Discipline:", Isoleucine_group["Zivah"]["Discipline"])
print("Preferred Language:", Isoleucine_group["Zivah"]["Preferred Language"])
print("\n")  # Adds a blank line for readability


print(3)
print("Full Name:", Isoleucine_group["Beulah"]["Full name"])
print("Slack Username:", Isoleucine_group["Beulah"]["Slack username"])
print("Email:", Isoleucine_group["Beulah"]["Email address"])
print("Hobby:", Isoleucine_group["Beulah"]["Hobby"])
print("Country:", Isoleucine_group["Beulah"]["Country"])
print("Discipline:", Isoleucine_group["Beulah"]["Discipline"])
print("Preferred Language:", Isoleucine_group["Beulah"]["Preferred Language"])
print("\n")  # Adds a blank line for readability


print(4)
print("Full Name:", Isoleucine_group["Feyisola"]["Full name"])
print("Slack Username:", Isoleucine_group["Feyisola"]["Slack username"])
print("Email:", Isoleucine_group["Feyisola"]["Email address"])
print("Hobby:", Isoleucine_group["Feyisola"]["Hobby"])
print("Country:", Isoleucine_group["Feyisola"]["Country"])
print("Discipline:", Isoleucine_group["Feyisola"]["Discipline"])
print("Preferred Language:", Isoleucine_group["Feyisola"]["Preferred Language"])
print("\n")  # Adds a blank line for readability


print(5)
print("Full Name:", Isoleucine_group["Irene"]["Full name"])
print("Slack Username:", Isoleucine_group["Irene"]["Slack username"])
print("Email:", Isoleucine_group["Irene"]["Email address"])
print("Hobby:", Isoleucine_group["Irene"]["Hobby"])
print("Country:", Isoleucine_group["Irene"]["Country"])
print("Discipline:", Isoleucine_group["Irene"]["Discipline"])
print("Preferred Language:", Isoleucine_group["Irene"]["Preferred Language"])
# Out:
# RESULTS FOR ISOLEUCINE GROUP
#
#
# 1
# Full Name: Chikesurum Woha
# Slack Username: Chikesurum
# Email: chikesurum@gmail.com
# Hobby: painting
# Country: United Kingdom
# Discipline: Biotechnology
# Preferred Language: Python
#
#
# 2
# Full Name: Zivah Woha
# Slack Username: Zivah
# Email: zivah@gmail.com
# Hobby: playing games
# Country: United Kingdom
# Discipline: medicine
# Preferred Language: Python
#
#
# 3
# Full Name: Beulah Agu
# Slack Username: Beulah
# Email: Beulah@gmail.com
# Hobby: singing
# Country: Nigeria
# Discipline: Biology
# Preferred Language: Python
#
#
# 4
# Full Name: Feyisola Adeyemi
# Slack Username: Feyisola
# Email: Feyisola@gmail.com
# Hobby: swimming
# Country: United Kingdom
# Discipline: Biotechnology
# Preferred Language: Python
#
#
# 5
# Full Name: Irene Abiodun
# Slack Username: Irene
# Email: Irene@gmail.com
# Hobby: swimming
# Country: United Kingdom
# Discipline: Biotechnology
# Preferred Language: Python
